# %%
#Q1
import torch
import torch.nn as nn
import torchvision.datasets as dset
import torchvision.transforms as transforms 
from torch.utils.data import DataLoader

training_epochs = 15
batch_size = 100

root = './data'
mnist_train = dset.MNIST (root=root, train=True, transform=transforms.ToTensor(), download=True)
mnist_test = dset.MNIST (root=root, train=False, transform=transforms.ToTensor(), download=True)

train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
#Q2
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
linear = nn.Linear(784, 10, bias=True).to(device)
nn.init.normal_(linear.weight)
# Out:
# Parameter containing:
# tensor([[ 8.1745e-01,  1.3056e+00,  1.3436e+00,  ...,  3.4325e-01,
#           2.1849e-01,  1.3682e+00],
#         [ 7.7091e-01, -7.5703e-01, -7.2685e-01,  ...,  2.0208e+00,
#          -4.7954e-01, -9.6738e-01],
#         [ 5.2352e-01,  1.3258e+00, -2.3370e+00,  ...,  8.1568e-01,
#           9.9950e-01, -4.4038e-01],
#         ...,
#         [-3.4703e-01, -1.9779e+00, -3.5522e-01,  ..., -2.8891e-01,
#           1.4133e+00,  1.2344e+00],
#         [ 7.8160e-01, -1.5010e+00,  8.1835e-01,  ...,  8.2310e-01,
#          -3.6889e-01, -8.5318e-01],
#         [-7.6017e-04,  3.7627e-01,  5.4603e-01,  ...,  5.5712e-01,
#           2.4318e-01,  9.6120e-01]], requires_grad=True)

# %%
#Q3
criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.SGD(linear.parameters(), lr=0.1)

# %%
#Q4

for epoch in range(training_epochs):
    for i, (imgs, labels) in enumerate(train_loader):
        imgs, labels = imgs.to(device), labels.to(device)
        imgs = imgs.view(-1, 28 * 28)
    
        outputs = linear(imgs)
        loss = criterion(outputs, labels)
    
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
        _,argmax = torch.max(outputs, 1)
        accuracy = (labels == argmax).float().mean()

        if (i+1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {: .4f}, Accuracy: {: .2f}%'.format(
            epoch+1, training_epochs, i+1, len(train_loader), loss.item(), accuracy.item()*100))
# Out:
# Epoch [1/15], Step [100/600], Loss:  3.6154, Accuracy:  45.00%
# Epoch [1/15], Step [200/600], Loss:  2.2439, Accuracy:  64.00%
# Epoch [1/15], Step [300/600], Loss:  1.9468, Accuracy:  63.00%
# Epoch [1/15], Step [400/600], Loss:  1.8062, Accuracy:  69.00%
# Epoch [1/15], Step [500/600], Loss:  1.2738, Accuracy:  66.00%
# Epoch [1/15], Step [600/600], Loss:  0.8760, Accuracy:  79.00%
# Epoch [2/15], Step [100/600], Loss:  1.0456, Accuracy:  78.00%
# Epoch [2/15], Step [200/600], Loss:  1.2121, Accuracy:  72.00%
# Epoch [2/15], Step [300/600], Loss:  1.5426, Accuracy:  74.00%
# Epoch [2/15], Step [400/600], Loss:  0.5888, Accuracy:  86.00%
# Epoch [2/15], Step [500/600], Loss:  0.6264, Accuracy:  83.00%
# Epoch [2/15], Step [600/600], Loss:  0.9488, Accuracy:  84.00%
# Epoch [3/15], Step [100/600], Loss:  0.7575, Accuracy:  81.00%
# Epoch [3/15], Step [200/600], Loss:  0.7013, Accuracy:  81.00%
# Epoch [3/15], Step [300/600], Loss:  1.0714, Accuracy:  74.00%
# Epoch [3/15], Step [400/600], Loss:  0.4981, Accuracy:  87.00%
# Epoch [10/15], Step [300/600], Loss:  0.5859, Accuracy:  88.00%
# Epoch [10/15], Step [400/600], Loss:  0.5750, Accuracy:  86.00%
# Epoch [10/15], Step [500/600], Loss:  0.6980, Accuracy:  81.00%
# Epoch [10/15], Step [600/600], Loss:  0.5750, Accuracy:  84.00%
# Epoch [11/15], Step [100/600], Loss:  0.4455, Accuracy:  88.00%
# Epoch [11/15], Step [200/600], Loss:  0.4054, Accuracy:  88.00%
# Epoch [11/15], Step [300/600], Loss:  0.6770, Accuracy:  88.00%
# Epoch [11/15], Step [400/600], Loss:  0.4715, Accuracy:  85.00%
# Epoch [11/15], Step [500/600], Loss:  0.3412, Accuracy:  91.00%
# Epoch [11/15], Step [600/600], Loss:  0.7278, Accuracy:  82.00%
# Epoch [12/15], Step [100/600], Loss:  0.4143, Accuracy:  91.00%
# Epoch [12/15], Step [200/600], Loss:  0.4053, Accuracy:  90.00%
# Epoch [12/15], Step [300/600], Loss:  0.2694, Accuracy:  91.00%
# Epoch [12/15], Step [400/600], Loss:  0.5687, Accuracy:  88.00%
# Epoch [12/15], Step [500/600], Loss:  0.4045, Accuracy:  92.00%
# Epoch [12/15], Step [600/600], Loss:  0.5736, Accuracy:  91.00%
# Epoch [13/15], Step [100/600], Loss:  0.4569, Accuracy:  83.00%
# Epoch [13/15], Step [200/600], Loss:  0.4519, Accuracy:  89.00%
# Epoch [13/15], Step [300/600], Loss:  0.2812, Accuracy:  90.00%
# Epoch [13/15], Step [400/600], Loss:  0.7054, Accuracy:  89.00%
# Epoch [13/15], Step [500/600], Loss:  0.4561, Accuracy:  90.00%
# Epoch [13/15], Step [600/600], Loss:  0.5444, Accuracy:  85.00%
# Epoch [14/15], Step [100/600], Loss:  0.3503, Accuracy:  91.00%
# Epoch [14/15], Step [200/600], Loss:  0.4496, Accuracy:  90.00%
# Epoch [14/15], Step [300/600], Loss:  0.5348, Accuracy:  88.00%
# Epoch [14/15], Step [400/600], Loss:  0.5663, Accuracy:  87.00%
# Epoch [14/15], Step [500/600], Loss:  0.6711, Accuracy:  87.00%
# Epoch [14/15], Step [600/600], Loss:  0.4866, Accuracy:  86.00%
# Epoch [15/15], Step [100/600], Loss:  0.2042, Accuracy:  93.00%
# Epoch [15/15], Step [200/600], Loss:  0.1819, Accuracy:  95.00%
# Epoch [15/15], Step [300/600], Loss:  0.5871, Accuracy:  87.00%
# Epoch [15/15], Step [400/600], Loss:  0.5118, Accuracy:  90.00%
# Epoch [15/15], Step [500/600], Loss:  0.6381, Accuracy:  86.00%
# Epoch [15/15], Step [600/600], Loss:  0.6514, Accuracy:  90.00%

# %%
#Q5

linear.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for i, (imgs, labels) in enumerate(test_loader):
        imgs, labels = imgs.to(device), labels.to(device)
        imgs = imgs.view(-1, 28 * 28)

        outputs = linear(imgs)

        _, argmax = torch.max(outputs, 1)
        total += imgs.size(0)
        correct += (labels == argmax).sum().item()

    print('Test accuracy for {} images: {: .2f}%'.format(total, correct / total * 100))
# Out:
# Test accuracy for 10000 images:  88.95%
