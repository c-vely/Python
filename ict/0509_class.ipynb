# %% [markdown]
# # matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t,t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
c, s = np.cos(x), np.sin(x)

pt1 = plt.plot(x, c)
pt2 = plt.plot(x, s)
print(pt1)
print(pt2)
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x0000023C45238F40>]
# [<matplotlib.lines.Line2D object at 0x0000023C45244220>]

# %%
fig1 = plt.figure(1)
pt1 = plt.plot(x, c)

fig2 = plt.figure(2)
pt2 = plt.plot(x, s)

print(pt1, pt2)
print(fig1, fig2)
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x0000023C45200B20>] [<matplotlib.lines.Line2D object at 0x0000023C451E8AF0>]
# Figure(640x480) Figure(640x480)

# %%
# %matplotlib inline

plt.plot([1,2,3,4,])
plt.ylabel('some numbers')
plt.show()

# %%
import sys

# %%
x = np.linspace(0, 10, 1000)
y = np.power(x, 2)
plt.plot(x, y)
plt.show()

# %%
plt.plot([1, 2, 3, 4], 'ro')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
x2 = [1, 2, 4, 6, 8]
y2 = [2, 4, 8, 12, 16]
plt.plot(x1, y1, 'r')
plt.plot(x2, y2, 'g')
plt.title('Plot of y vs x')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xlim(0.0, 9.0)
plt.ylim(0.0, 30.)
plt.show()

# %%
x = [1, 2, 3]
y = [1, 4, 9]
plt.plot(x, y, color='green', linestyle='dashed', marker='o', markerfacecolor='blue', markersize=12)
plt.show()

# %%
a = b = np.arange(0, 3,.02)
c = np.exp(a)
d = c[::-1]
plt.plot(a, c, 'k--', label='Model length')
plt.plot(a, d, 'k:', label='Data length')
plt.plot(a, c + d, 'k', label='Total message length')
plt.show()

# %%
a = b = np.arange(0, 3,.02)
c = np.exp(a)
d = c[::-1]
plt.plot(a, c, 'k--', label='Model length')
plt.plot(a, d, 'k:', label='Data length')
plt.plot(a, c + d, 'k', label='Total message length')
plt.legend()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
plt.plot(x, y, linewidth = 6.0)
plt.show()

# %%
# AXES 설명
f, ax = plt.subplots(1, 1, figsize=(5, 4))
print(f)
print(ax)
x = np.linspace(0, 10, 1000)
y = np.power(x, 2)
ax.plot(x, y)
ax.set_xlim((1, 5))
ax.set_ylim((0, 30))
ax.set_xlabel('my x label')
ax.set_ylabel('my y label')
ax.set_title('plot title, including $\Omega$')
plt.tight_layout()
plt.savefig('line_plot_plus.pdf')
# Out:
# Figure(500x400)
# Axes(0.125,0.11;0.775x0.77)

# %%
data = np.random.rand(10, 2)
data
# Out:
# array([[0.57805413, 0.58297981],
#        [0.8027299 , 0.4699152 ],
#        [0.90694389, 0.74261213],
#        [0.63242086, 0.23398323],
#        [0.00495154, 0.32471615],
#        [0.86213659, 0.38221894],
#        [0.16131857, 0.58836806],
#        [0.40768055, 0.74574946],
#        [0.41423187, 0.14977991],
#        [0.46841123, 0.36786928]])

# %%
print(data.shape)
# Out:
# (10, 2)

# %%
plt.scatter(data[:,0], data[:,1])
plt.show()

# %%
x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 + y**2)

plt.subplot(321)
plt.scatter(x, y, s=80, c=z, marker='>')
plt.show()

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
ind = np.arange(N)
plt.bar(ind, menMeans)
plt.show()

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
ind = np.arange(N)
plt.bar(ind, menMeans, width=1.0, color='r')
plt.show()

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
ind = np.arange(N)
plt.bar(ind, menMeans, width=0.5, color='y')
plt.show()

# %%
N = 5
width = 0.33
menMeans = (20, 35, 30, 35, 27)
wonMeans = (25, 32, 34, 20, 25)
ind = np.arange(N)
p1 = plt.bar(ind + 0.00, menMeans, width, color='r')
p2 = plt.bar(ind + 0.33, wonMeans, width, color='g')
plt.xlabel('The number of people')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind + width/2., ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))
plt.show()

# %%
w_pop = np.array([5, 30, 45, 40], dtype=np.float32)
m_pop = np.array([4, 28, 40, 35], dtype=np.float32)
x = np.arange(4)

a = plt.barh(x, w_pop, color='r')
b = plt.barh(x, -m_pop)

print(a)
print(b)
plt.show()
# Out:
# <BarContainer object of 4 artists>
# <BarContainer object of 4 artists>

# %%
data = [5, 10, 30, 20, 7, 8, 10, 10]
plt.pie(data)
plt.show()

# %%
data = [5, 10, 30, 20, 7, 8, 10, 10]
label = ['Blue', 'Green', 'Red', 'Cyan', 'Magenta', 'Yellow', 'Black', 'White']
plt.pie(data, labels = label)
plt.show()

# %%
data = np.random.normal(5.0, 3.0, 1000)
plt.hist(data)
plt.xlabel('data')
plt.show()

# %%
data = np.random.normal(5.0, 3.0, 1000)
plt.hist(data, bins = 15)
plt.xlabel('data')
plt.show()

# %%
data = np.random.normal(5.0, 3.0, 1000)
plt.hist(data, facecolor='red', alpha=0.4, histtype='stepfilled')

bins = np.arange(-5., 16., 1.)
plt.hist(data, bins, histtype='stepfilled')

plt.xlabel('data')
plt.show()

# %%
data = np.random.randn(1000)
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 3))
print(ax1)
print(ax2)
ax1.hist(data, bins=30, color='b')
ax2.hist(data, bins=30, color='r', cumulative=True)
plt.show()
# Out:
# AxesSubplot(0.125,0.11;0.352273x0.77)
# AxesSubplot(0.547727,0.11;0.352273x0.77)

# %%
samp1 = np.random.normal(loc=0, scale=1, size=100)
samp2 = np.random.normal(loc=1, scale=2, size=100)
samp3 = np.random.normal(loc=0.3, scale=1.2, size=100)
plt.boxplot((samp1, samp2, samp3))
plt.show()

# %%
samp1 = np.random.normal(loc=0, scale=1, size=100)
samp2 = np.random.normal(loc=1, scale=2, size=100)
samp3 = np.random.normal(loc=0.3, scale=1.2, size=100)
f, ax = plt.subplots(1, 1, figsize=(5 ,4))
ax.boxplot((samp1, samp2, samp3))
ax.set_xticklabels(['sample 1', 'sample 2', 'sample 3'])
plt.show()

# %%
A = np.random.random((100, 100))
plt.imshow(A)
plt.hot()
plt.colorbar()
plt.show()

# %%
import matplotlib.image as mpimg
img = mpimg.imread("sample.jpg")
print(type(img))
plt.imshow(img)
plt.hot()
plt.colorbar()
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
import matplotlib.image as mpimg
img = mpimg.imread("sample.jpg")
print(type(img))
plt.imshow(img)
plt.hot()
plt.colorbar()
plt.axis('off')
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
x = np.linspace(0, 10, 101)
sp1 = plt.subplot(2, 2, 1)
y = np.exp(x)
l1 = plt.semilogy(x, y, color='m', linewidth=2)
lx = plt.xlabel('x')
ly = plt.ylabel('y')
tl = plt.title('y = exp(x)')
print(sp1)

sp2 = plt.subplot(2, 2, 2)
y = x**1.67
l1 = plt.loglog(x, y)
lx = plt.xlabel('x')
ly = plt.ylabel('y')
tl = plt.title('y = x$^{-5/3}$')
print(sp2)

plt.show()
# Out:
# AxesSubplot(0.125,0.53;0.352273x0.35)
# AxesSubplot(0.547727,0.53;0.352273x0.35)
