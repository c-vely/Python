# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
t = np.arange(0.,5., 0.2)
plt.plot(t, t, 'r--', t,t**2, 'bs',t, t**3,'g^')
plt.show()

# %%
x = np.linspace(-np.pi, np.pi,256, endpoint= True)
C, S = np.cos(x),np.sin(x)

# %%
plt1 = plt.plot(x,C)
plt2 = plt.plot(x,S)
print(plt1)
print(plt2)
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x000001EBE9471B50>]
# [<matplotlib.lines.Line2D object at 0x000001EBE9471EE0>]

# %%
fig1 = plt.figure(1)
pt1 = plt.plot(x,C)
fig2 = plt.figure(2)
pt2 = plt.plot(x,S)
print(pt1)
print(pt2)
print(fig1)
print(fig2)
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x000001EBE94E6E20>]
# [<matplotlib.lines.Line2D object at 0x000001EBE952D760>]
# Figure(432x288)
# Figure(432x288)

# %%
# %matplotlib inline
plt.plot([1,2,3,4])
plt.ylabel("some numbers")
plt.show()

# %%
import seaborn as sns

# %%
 x = np.linspace(0,10,1000)

# %%
y = np.power(x,2)
plt.plot(x,y)
plt.show()

# %%
plt.plot([1,2,3,4], 'ro')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]
x2 = [1,2,4,6,8]
y2 = [2,4,8,12,16]
plt.plot(x1,y1,'r')
plt.plot(x2,y2,'g')
plt.title('Plot of y vs x')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xlim(0.0, 9.0)
plt.ylim(0.0,30.)
plt.show()

# %%
x = [1,2,3]
y = [1,4,9]

# %%
plt.plot(x,y, color ='green', linestyle = 'dashed', marker ='o',
        markerfacecolor='blue',markersize=12)
plt.show()

# %%
a = b = np.arange(0,3,.02)
c = np.exp(a)
d = c[::-1]

# %%
plt.plot(a,c, 'k--', label='Model length')
plt.plot(a,d,'k:',label='Data length')
plt.plot(a,c+d, 'k', label='Total message length')
plt.show()

# %%
a = b = np.arange(0,3,.02)
c = np.exp(a)
d = c[::-1]
plt.plot(a,c, 'k--', label='Model length')
plt.plot(a,d,'k:',label='Data length')
plt.plot(a,c+d, 'k', label='Total message length')
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
plt.plot(x,y,linewidth=3.0)
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
plt.plot(x,y,linewidth=6.0)
plt.show()
plt.savefig('line_width_plus.pdf')

# %%
# AXES 설명

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
f, ax = plt.subplots(1,1,figsize=(5,4))
print(f)
print(ax)
# Out:
# Figure(360x288)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
x = np.linspace(0, 10,1000)
y = np.power(x,2)

# %%
ax.plot(x,y)
ax.set_xlim((1,5))
ax.set_ylim((0,30))
ax.set_xlabel(('my x label'))
ax.set_ylabel(('my y label'))
ax.set_title('plot title, including $\Omega$')

plt.tight_layout()
plt.savefig('line_plot_plus.pdf')

# %%
data = np.random.rand(10,2)
data
# Out:
# array([[0.09762067, 0.3199413 ],
#        [0.09676539, 0.18263909],
#        [0.17120583, 0.90219554],
#        [0.66097278, 0.56799153],
#        [0.51135304, 0.20097242],
#        [0.29417629, 0.40271895],
#        [0.80667757, 0.88906743],
#        [0.7968042 , 0.40443509],
#        [0.28379149, 0.23364964],
#        [0.56908694, 0.7848273 ]])

# %%
print(data.shape)
# Out:
# (10, 2)

# %%
plt.scatter(data[:,0],data[:,1])
plt.show()

# %%
x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 +y**2)

# %%
plt.subplot(321)
plt.scatter(x,y, s=80, c= z,marker=">")
plt.show()

# %%
plt.subplot(321)
plt.scatter(x,y, s=40, c= z,marker=">")
plt.show()

# %%
N = 5
menMeans = (20,35,30,35,27)
ind = np.arange(N)
plt.bar(ind, menMeans)
plt.show()

# %%
N = 5
menMeans = (20,35,30,35,27)
ind = np.arange(N)
#plt.bar(ind, menMeans)
plt.bar(ind, menMeans, width=1.0, color='r')
plt.show()

# %%
N = 5
menMeans = (20,35,30,35,27)
ind = np.arange(N)
#plt.bar(ind, menMeans)
plt.bar(ind, menMeans, width=0.5, color='r')
plt.show()

# %%
N = 5 
menMeans = (20,35,30,35,27)
womenMeans=(25,32,34,20,25)
p1 = plt.bar(ind+0.00, menMeans, width=0.33, color='r')
p2= plt.bar(ind+0.33, womenMeans,width=0.33,color ='y')
plt.xlabel('The number of people')
plt.ylabel('Scores')

plt.xticks(ind + 0.33/2., ('G1','G2','G3','G4','G5'))
plt.yticks(np.arange(0,81,10))
plt.legend((p1[0],p2[0],('Men','Women')))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1320/2914238650.py in <module>
#       9 plt.xticks(ind + 3/2., ('G1','G2','G3','G4','G5'))
#      10 plt.yticks(np.arange(0,81,10))
# ---> 11 plt.legend((p1[0],p2[0],('Men','Women')))
#      12 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    2915 @_copy_docstring_and_deprecators(Axes.legend)
#    2916 def legend(*args, **kwargs):
# -> 2917     return gca().legend(*args, **kwargs)
#    2918
#    2919
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     282         .. plot:: gallery/text_labels_and_annotations/legend.py
#     283         """
# --> 284         handles, labels, extra_args, kwargs = mlegend._parse_legend_args(
#     285                 [self],
#     286                 *args,
#
# ~\anaconda3\lib\site-packages\matplotlib\legend.py in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1232         labels, = args
#    1233         if any(isinstance(l, Artist) for l in labels):
# -> 1234             raise TypeError("A single argument passed to legend() must be a "
#    1235                             "list of labels, but found an Artist in there.")
#    1236
#
# TypeError: A single argument passed to legend() must be a list of labels, but found an Artist in there.

# %%
w_pop = np.array([5,30,45,40],dtype=np.float32)
m_pop = np.array([4,28,40,35],dtype=np.float32)
x = np.arange(4)

a = plt.barh(x,w_pop,color='r')
b = plt.barh(x,-m_pop)
plt.show()

# %%
data = [5,10,30,20,7,8,10,10]
plt.pie(data)
plt.show()

# %%
data = [5,10,30,20,7,8,10,10]
label =['Blue','Green','Red','Cyan','Magenta','Yellow','Black','White']
plt.pie(data,labels=label)
plt.show()

# %%
data = np.random.normal(5.0,3.0,1000)
plt.hist(data)
plt.xlabel('data')
plt.show()

# %%
data = np.random.normal(5.0,3.0,1000)
plt.hist(data,bins=15)
plt.xlabel('data')
plt.show()

# %%
data= np.random.normal(5.0, 3.0, 1000)
plt.hist(data,facecolor='red',alpha=0.7,histtype='stepfilled')
bins = np.arange(-5.,16.,1.)
plt.hist(data,bins,histtype='stepfilled')
plt.xlabel('data')
plt.show()

# %%
data = np.random.randn(1000)
f,(ax1,ax2) = plt.subplots(1,2,figsize=(6,3))
print(ax1)
print(ax2)
ax1.hist(data, bins = 30, normed=True, color='b')
ax2.hist(data, bins=30, normed=True,color='r',cumulative=True)
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.352273x0.755)
# AxesSubplot(0.547727,0.125;0.352273x0.755)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1320/402522478.py in <module>
#       3 print(ax1)
#       4 print(ax2)
# ----> 5 ax1.hist(data, bins = 30, normed=True, color='b')
#       6 ax2.hist(data, bins=30, normed=True,color='r',cumulative=True)
#       7 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6909             if patch:
#    6910                 p = patch[0]
# -> 6911                 p.update(kwargs)
#    6912                 if lbl is not None:
#    6913                     p.set_label(lbl)
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1060                     func = getattr(self, f"set_{k}", None)
#    1061                     if not callable(func):
# -> 1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
#    1064                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
samp1 = np.random.normal(loc=0., scale=1., size=100)
samp2 = np.random.normal(loc=1., scale=2., size =100)
samp3 = np.random.normal(loc=0.3, scale=1.2, size=100)
plt.boxplot((samp1,samp2,samp3))
plt.show()

# %%
samp1 = np.random.normal(loc=0., scale=1., size=100)
samp2 = np.random.normal(loc=1., scale=2., size =100)
samp3 = np.random.normal(loc=0.3, scale=1.2, size=100)
f,ax =plt.subplots(1,1,figsize=(5,4))
ax.boxplot((samp1,samp2,samp3))
ax.set_xticklabels(['sample 1','sample 2','sample 3'])
plt.show()

# %%
A = np.random.random((100,100))
plt.imshow(A)
plt.hot()
plt.colorbar()
plt.show()

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread("A.jpg")
print(type(img))
plt.imshow(img)
plt.hot()
plt.colorbar()
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
img = mpimg.imread("A.jpg")
print(type(img))
plt.imshow(img)
plt.hot()
plt.colorbar()
plt.axis("off")
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
x = np.linspace(0,10,10)
sp1 = plt.subplot(2,2,1)
y= np.exp(x)
l1 = plt.semilogy(x,y, color='m', linewidth=2)
lx = plt.xlabel("x")
ly = plt.ylabel("y")
t1 =plt.title("y = exp(x)")
print(sp1)

sp2 = plt.subplot(2,2,2)
y= x** - 1.67
l1 = plt.loglog(x,y)
lx = plt.xlabel("x")
ly = plt.ylabel("y")
t1 =plt.title("y = x$^{-5/3}$)")
print(sp2)
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.352273x0.343182)
# AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# C:\Users\kchan\AppData\Local\Temp/ipykernel_1320/361324657.py:11: RuntimeWarning: divide by zero encountered in power
#   y= x** - 1.67
