# %%
import numpy as np
from matplotlib import pyplot as plt

sample1 = 200 + np.random.randn(10)
print(sample1)

sample2 = 200 + np.random.randn(10)
print(sample2)

print(abs(sample1-sample2))

x = [x for x in range(len(sample2))]
plt.plot(x, sample1, '-')
plt.plot(x, sample2, '-')
plt.fill_between(x, sample1, np.maximum(sample1, sample2),
                 where=(abs(sample1-sample2) > 1), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
# Out:
# [200.97676568 198.67987677 200.85876007 200.35089306 200.14343312
#  199.60104123 200.73652091 200.52075208 200.2152332  201.45797412]
# [198.63212579 200.730672   199.09529484 199.62737941 199.10751919
#  200.115412   201.22253371 199.84661857 199.95153718 197.89451808]
# [2.34463989 2.05079523 1.76346523 0.72351365 1.03591393 0.51437078
#  0.4860128  0.67413351 0.26369602 3.56345604]
